# %%
# Importamos nuestra librerías básicas
import numpy as np
import os
import itertools

from sklearn.datasets import fetch_mldata
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import seaborn as sns
import graphviz

# Este paso es para que los resultados en vuestros notebooks sean iguales a lo de este
np.random.seed(42)

# %% [markdown]
# # Aprendizaje supervisado - *Decision Trees*
# El algoritmo de *Decision Trees* se basa en crear un árbol que va separando las instancias por un umbral en las características de forma a poder inferir en sus hojas a que clase corresponde cada instancia. Para esta separación se utiliza una medida de "pureza".

# %%
# Cargamos el dataset
iris = load_iris()
# Separamos el dataset en 2 partes: el training set y test set
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.65, random_state=42)
print(X_train[:4,])
# Creamos el modelo
clf = DecisionTreeClassifier()
# Entrenamos el modelo
clf = clf.fit(X_train, y_train)
# Out:
# [[ 6.   2.2  5.   1.5]
#  [ 7.2  3.2  6.   1.8]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.1  3.5  1.4  0.3]]

# %%
# Visualizamos los datos en 3D
plt.figure(figsize=(9,9))
ax = plt.subplot(projection='3d')
ax.scatter3D(X_train[:,0], X_train[:,2], X_train[:,3], c=y_train, s=50, cmap='winter')
ax.azim=10
ax.elev=15
plt.show()

# %%
# El sklearn en su guia explica como visualizar un árbol.
# Para eso utilizaremos la librería graphviz para visualizar el árbol
export_graphviz(clf, filled=True, rounded=True, 
                special_characters=True, out_file="mytree.dot")
with open("mytree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
# Medimos el rendimiento
# %time train_score = clf.score(X_train, y_train)
print("Rendimiento en el dataset de training: %.4f" % train_score)
# %time cv_score = cross_val_score(clf, X_train, y_train, cv=5)
print("Rendimiento en la cross-validación: %.4f" % np.mean(cv_score))
# %time score = clf.score(X_test, y_test)
print("Rendimiento en el dataset de pruebas: %.4f" % score)
# Out:
# Wall time: 0 ns
# Rendimiento en el dataset de training: 1.0000
# Wall time: 8 ms
# Rendimiento en la cross-validación: 0.9833
# Wall time: 0 ns
# Rendimiento en el dataset de pruebas: 0.8980

# %% [markdown]
# # Ahora vamos a clasificar el MNIST

# %%
# Aqui importamos los datos que vamos a clasificar

# Scikit-Learn ya incluye algunos datasets de ejemplo como el MNIST
mnist = fetch_mldata('MNIST original')

# Aqui cargamos nuestros ejemplos en X, el target en y. Nuestro objetivo con
# Machine Learning es aprender la función f(X) que genera y.
X, y = mnist["data"], mnist["target"]

# %%
# Nuestro objetivo es que la función aprendida funcione no solamente con
# el dataset de prueba, pero que también "generalize" bien para ejemplos
# que no haya visto antes.

# En esta sección separamos el dataset en 2 partes: el training set y test set
X_train_o, X_test_o, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ## Clasificador *Decision Tree*

# %%
# Creamos el modelo
tree_clf = DecisionTreeClassifier(random_state=42)

# Hacemos fit del modelo al dato
# %time tree_clf.fit(X_train_o, y_train)
# Out:
# Wall time: 22 s
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
# Medimos el rendimiento.
# %time train_score = tree_clf.score(X_train_o, y_train)
print("Rendimiento en el dataset de training: %.4f" % train_score)
# %time cv_score = cross_val_score(tree_clf, X_train_o, y_train, cv=5)
print("Rendimiento en la cross-validación: %.4f" % np.mean(cv_score))
# %time score = tree_clf.score(X_test_o, y_test)
print("Rendimiento en el dataset de pruebas: %.4f" % score)
# Out:
# Wall time: 159 ms
# Rendimiento en el dataset de training: 1.0000
# Wall time: 1min 16s
# Rendimiento en la cross-validación: 0.8668
# Wall time: 24.1 ms
# Rendimiento en el dataset de pruebas: 0.8757

# %%
# Esta función esta adaptada de la documentación del Scikit-Learn para presentar
# la matrix de "confusión" de forma más visual
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    #else:
        #print('Confusion matrix, without normalization')
        

    #print(cm)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel("Valor real")
    plt.xlabel("Predicción")
    plt.show()

# %%
# La confusion matrix nos presenta una información sumaria de la precisión y del recall
cm=confusion_matrix(y_test, tree_clf.predict(X_test_o))
plt.figure(figsize=(8,8))
plot_confusion_matrix(cm, classes=["zero","uno","dos","tres","cuatro","cinco","seis","siete","ocho","nueve"], normalize=True);

# %% [markdown]
# # *Overfitting* y *underfitting*
#
# Surgen del dilema variance x bias
#
# - *Overfitting* - Variance
#   - Se adapta bien a los datos de entrenamiento
#   - Captura las *features* pero también el ruído del set de entrenamiento
#   - No generaliza bien a nuevas instancias
#
# - *Underfitting* - bias
#   - El modelo no es suficientemente *complejo*
#   - No consigue capturar las *features*
#   - Con lo cual tampoco generaliza bien a nuevas instancias

# %% [markdown]
# # Como resolver
#
# - Optimización de *hyperparameters* con cross-validación
#     - Parametros de regularización - disminuyen la capacidad del modelo a adaptarse a los datos
# - Selección de *features*
#   - Eliminar las *features* que no ayudan - menos ruído
#   - No incluir *features* muy correlacionadas
# - Normalización y transformación de *features*
#   - Las *features* son "normales"? (requerimiento de algunos modelos)
# - *Ensembles* - Modelos agregados

# %%
# Ejemplo de optimización de parámetros

parameters = [
    {'max_depth': [None, 15, 16, 17]}
]
clf = GridSearchCV(tree_clf, parameters, scoring='accuracy', cv=5)
# %time clf.fit(X_train_o, y_train)
# Out:
# Wall time: 4min 37s
# GridSearchCV(cv=5, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=3e-05,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'max_depth': [None, 15, 16, 17]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# Resultados
print("Mejores parametros en el training set", clf.best_params_)
# Out:
# Mejores parametros en el training set {'max_depth': 16}

# %%
# Creamos el modelo con los parametros indicados
tree_clf = DecisionTreeClassifier(max_depth=16, random_state=42)

# Hacemos fit del modelo al dato
# %time tree_clf.fit(X_train_o, y_train)
# Out:
# Wall time: 15.6 s
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=16,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
# Medimos el rendimiento.
# %time train_score = tree_clf.score(X_train_o, y_train)
print("Rendimiento en el dataset de training: %.4f" % train_score)
# %time cv_score = cross_val_score(tree_clf, X_train_o, y_train, cv=5)
print("Rendimiento en la cross-validación: %.4f" % np.mean(cv_score))
# %time score = tree_clf.score(X_test_o, y_test)
print("Rendimiento en el dataset de pruebas: %.4f" % score)
# Out:
# Wall time: 172 ms
# Rendimiento en el dataset de training: 0.9896
# Wall time: 59.6 s
# Rendimiento en la cross-validación: 0.8702
# Wall time: 27 ms
# Rendimiento en el dataset de pruebas: 0.8812
